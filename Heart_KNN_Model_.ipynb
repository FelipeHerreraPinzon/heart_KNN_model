# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score


X_train = pd.read_csv('X_train_heart.csv')
X_train = X_train.dropna(axis=0)
X_train
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     54    0   3       108   267    0        2      167      0      0.0
# 1     60    0   3       120   178    1        0       96      0      0.0
# 2     48    1   4       122   222    0        2      186      0      0.0
# 3     60    0   4       158   305    0        2      161      0      0.0
# 4     65    0   3       140   417    1        2      157      0      0.8
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 206   64    1   4       128   263    0        0      105      1      0.2
# 207   54    1   3       125   273    0        2      152      0      0.5
# 209   45    0   4       138   236    0        2      152      1      0.2
# 210   64    1   4       145   212    0        2      132      0      2.0
# 211   51    1   3       100   222    0        0      143      1      1.2
#
#      slope   ca  thal
# 0        1  0.0   3.0
# 1        1  0.0   3.0
# ...

# %%
y_train = pd.read_csv('y_train_heart.csv')
y_train = y_train.dropna(axis=0)
y_train
# Out:
#      num
# 0      0
# 1      0
# 2      0
# 3      1
# 4      0
# ..   ...
# 207    0
# 208    0
# 209    0
# 210    4
# 211    0
#
# [212 rows x 1 columns]

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score

# Cargar datos desde los archivos CSV
X_train = pd.read_csv('X_train_heart.csv')
y_train = pd.read_csv('y_train_heart.csv')

# Eliminar filas con NaN de ambos conjuntos de datos
X_train_clean = X_train.dropna(axis=0)
y_train_clean = y_train.dropna(axis=0)

# Asegurar que las filas eliminadas de X_train coincidan con las filas eliminadas de y_train
y_train_clean = y_train_clean.iloc[X_train_clean.index]

# Convertir y_train_clean a un array unidimensional
y_train_clean = y_train_clean.values.ravel()

# Dividir el conjunto de datos limpio en entrenamiento y prueba
X_train_final, X_test, y_train_final, y_test = train_test_split(X_train_clean, y_train_clean, test_size=0.2, random_state=42)

# Crear un clasificador k-NN
knn_heart_model = KNeighborsClassifier(n_neighbors=10)

# Entrenar el clasificador con el conjunto de entrenamiento
knn_heart_model.fit(X_train_final, y_train_final)

# Predecir las etiquetas del conjunto de prueba
y_pred = knn_heart_model.predict(X_test)

accuracy = accuracy_score(y_test, y_pred)
print("Precisión del modelo k-NN:", accuracy)
# Out:
# Precisión del modelo k-NN: 0.5238095238095238

# %%
import pickle

# Guardar el modelo en un archivo usando pickle
with open('knn_heart_model.pkl', 'wb') as archivo:
    pickle.dump(knn_heart_model, archivo)
